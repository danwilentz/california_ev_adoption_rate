# %%
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs
import pandas as pd

# %%
# Read in geojsons for California zip codes and counties

zip_codes = gpd.read_file("California_Zip_Codes.geojson")
counties = gpd.read_file("California_County_Boundaries.geojson")

print(f'California has {len(zip_codes)} zip codes and {len(counties)} counties')
# Out:
# California has 1721 zip codes and 69 counties

# %%
zip_codes.sample(1)
# Out:
#       OBJECTID ZIP_CODE PO_NAME STATE  POPULATION  POP_SQMI    SQMI  \
# 1387      1388    95503  Eureka    CA       24479    221.37  110.58
#
#       SHAPE_Length  SHAPE_Area  \
# 1387      1.343002     0.03052
#
#                                                geometry
# 1387  MULTIPOLYGON (((-124.04885 40.80275, -124.0611...

# %%
counties.sample(1)
# Out:
#     OBJECTID COUNTY_NAME COUNTY_ABBREV  COUNTY_NUM COUNTY_CODE COUNTY_FIPS  \
# 52        53     Trinity           TRI          53          53         105
#
#    ISLAND                                GlobalID  SHAPE_Length  SHAPE_Area  \
# 52    NaN  {2CDCC639-3309-4168-9D1F-F9C64504994D}      6.289429    0.884508
#
#                                              geometry
# 52  MULTIPOLYGON (((-122.56594 41.36550, -122.5657...

# %%
# Drop unecessary columns
zip_codes.drop(columns = ['OBJECTID', 'STATE', 'SHAPE_Length', 'SHAPE_Area'], inplace = True)
counties.drop(columns = ['OBJECTID', 'COUNTY_NUM', 'COUNTY_CODE'], inplace = True)

# Lowercase columns 
zip_codes.columns= zip_codes.columns.str.lower()
counties.columns = counties.columns.str.lower()

# rename zip_code geom column
zip_codes.rename_geometry('zip_code_geometry', inplace=True)

# create duplicate county geometry column, because original county geometry column will be lost during the join
counties['county_geometry'] = counties.geometry

# %%
print(zip_codes.columns)
print(counties.columns)
# Out:
# Index(['zip_code', 'po_name', 'population', 'pop_sqmi', 'sqmi',
#        'zip_code_geometry'],
#       dtype='object')
# Index(['county_name', 'county_abbrev', 'county_fips', 'island', 'globalid',
#        'shape_length', 'shape_area', 'geometry', 'county_geometry'],
#       dtype='object')

# %%
# Reset CRS from 4326 to 3857
# This effectively sets our coordinate system from a globe to a map, which is necessary before we compute centroids

zip_codes.to_crs(3857, inplace = True)
counties.to_crs(3857, inplace = True)

# %%
# Calculate zip code centroids - each centroid will be mapped to a county
zip_codes['zip_code_centroid'] = zip_codes.centroid

# %%
# Set the zip code active geometry to the centroid column
# Then join counties onto zip codes by using zip code centroids intersecting with county polygons
zip_codes.set_geometry('zip_code_centroid', inplace=True)
zip_codes_with_county=gpd.sjoin(zip_codes, counties, how='inner',predicate='intersects')

# %%
len(zip_codes_with_county)
# Out:
# 1717

# %% [markdown]
# Our join lost us 4 zip codes out of 1721. We'll consider that fine

# %%
zip_codes_with_county
# Out:
#      zip_code            po_name  population  pop_sqmi     sqmi  \
# 0       00012    Mt Meadows Area         -99    -99.00    30.92
# 4       00019  Lassen Ntl Forest         -99    -99.00   412.59
# 1654    96056           McArthur        2670      1.26  2119.67
# 1686    96109              Doyle         994      4.27   232.99
# 1689    96113            Herlong        2080      6.45   322.53
# ...       ...                ...         ...       ...      ...
# 1681    96104         Cedarville         800      2.37   337.07
# 1685    96108        Davis Creek         268      0.20  1329.33
# 1688    96112       Fort Bidwell         119      0.88   134.67
# 1691    96115          Lake City         188      0.87   215.41
# 1692    96116             Likely         256      0.80   318.75
#
#                                       zip_code_geometry  \
# 0     MULTIPOLYGON (((-13452238.667 4902283.104, -13...
# 4     MULTIPOLYGON (((-13358184.384 4978709.393, -13...
# 1654  MULTIPOLYGON (((-13499920.701 5108151.017, -13...
# 1686  MULTIPOLYGON (((-13358027.535 4877354.506, -13...
# 1689  MULTIPOLYGON (((-13357905.528 4924612.177, -13...
# ...                                                 ...
# 1681  MULTIPOLYGON (((-13358180.376 5098481.771, -13...
# 1685  MULTIPOLYGON (((-13451922.965 5160063.191, -13...
# 1688  MULTIPOLYGON (((-13358246.277 5160161.747, -13...
# 1691  MULTIPOLYGON (((-13358153.103 5124433.704, -13...
# 1692  MULTIPOLYGON (((-13386949.118 5060290.605, -13...
#
#                       zip_code_centroid  index_right county_name  \
# 0     POINT (-13463053.884 4900376.323)           17      Lassen
# 4     POINT (-13375339.563 4951485.501)           17      Lassen
# 1654  POINT (-13482543.925 5006144.892)           17      Lassen
# 1686  POINT (-13368753.739 4859102.251)           17      Lassen
# 1689  POINT (-13377162.899 4901611.383)           17      Lassen
# ...                                 ...          ...         ...
# 1681  POINT (-13371575.020 5071040.563)           24       Modoc
# 1685  POINT (-13444301.133 5133572.133)           24       Modoc
# 1688  POINT (-13370050.824 5146304.643)           24       Modoc
# 1691  POINT (-13372876.672 5115447.110)           24       Modoc
# 1692  POINT (-13415403.662 5051227.355)           24       Modoc
#
#      county_abbrev county_fips island                                globalid  \
# 0              LAS         035    NaN  {0CB818C3-7995-42E7-9E8D-7563B81B9049}
# 4              LAS         035    NaN  {0CB818C3-7995-42E7-9E8D-7563B81B9049}
# 1654           LAS         035    NaN  {0CB818C3-7995-42E7-9E8D-7563B81B9049}
# 1686           LAS         035    NaN  {0CB818C3-7995-42E7-9E8D-7563B81B9049}
# 1689           LAS         035    NaN  {0CB818C3-7995-42E7-9E8D-7563B81B9049}
# ...            ...         ...    ...                                     ...
# 1681           MOD         049    NaN  {86F15375-C4E1-4A0E-A363-9099286C17AF}
# 1685           MOD         049    NaN  {86F15375-C4E1-4A0E-A363-9099286C17AF}
# 1688           MOD         049    NaN  {86F15375-C4E1-4A0E-A363-9099286C17AF}
# 1691           MOD         049    NaN  {86F15375-C4E1-4A0E-A363-9099286C17AF}
# 1692           MOD         049    NaN  {86F15375-C4E1-4A0E-A363-9099286C17AF}
#
#       shape_length  shape_area  \
# 0         5.976298    1.302337
# 4         5.976298    1.302337
# 1654      5.976298    1.302337
# 1686      5.976298    1.302337
# 1689      5.976298    1.302337
# ...            ...         ...
# 1681      4.539512    1.175396
# 1685      4.539512    1.175396
# 1688      4.539512    1.175396
# 1691      4.539512    1.175396
# 1692      4.539512    1.175396
#
#                                         county_geometry
# 0     MULTIPOLYGON (((-119.99981 41.18426, -119.9997...
# 4     MULTIPOLYGON (((-119.99981 41.18426, -119.9997...
# 1654  MULTIPOLYGON (((-119.99981 41.18426, -119.9997...
# 1686  MULTIPOLYGON (((-119.99981 41.18426, -119.9997...
# 1689  MULTIPOLYGON (((-119.99981 41.18426, -119.9997...
# ...                                                 ...
# 1681  MULTIPOLYGON (((-121.34719 41.99647, -121.3397...
# 1685  MULTIPOLYGON (((-121.34719 41.99647, -121.3397...
# 1688  MULTIPOLYGON (((-121.34719 41.99647, -121.3397...
# 1691  MULTIPOLYGON (((-121.34719 41.99647, -121.3397...
# 1692  MULTIPOLYGON (((-121.34719 41.99647, -121.3397...
#
# [1717 rows x 16 columns]

# %% [markdown]
# # Analytics

# %%
# Plot zip codes
zip_codes_with_county.set_geometry('county_geometry', inplace = True)
geoplot.polyplot(zip_codes_with_county, projection=gcrs.AlbersEqualArea(), 
                 edgecolor='darkgrey', 
                 facecolor='lightblue', 
                 linewidth=.3,
                 figsize=(12, 8))
# Out:
# <GeoAxes: >

# %%
num_zip_codes_per_county = zip_codes_with_county.groupby('county_name')['zip_code'].nunique()
num_zip_codes_per_county.sort_values(ascending = False)
# Out:
# county_name
# Los Angeles        289
# San Diego          108
# San Bernardino      92
# Orange              87
# Riverside           71
# Santa Clara         61
# Sacramento          53
# Fresno              52
# Alameda             49
# Kern                46
# Contra Costa        41
# Humboldt            33
# Sonoma              31
# Ventura             30
# San Mateo           30
# Placer              30
# Tulare              28
# Marin               28
# San Joaquin         27
# Monterey            27
# San Francisco       26
# Mendocino           26
# Santa Barbara       25
# Shasta              23
# Siskiyou            23
# El Dorado           23
# Stanislaus          23
# San Luis Obispo     20
# Plumas              20
# Merced              17
# Yolo                16
# Butte               15
# Solano              14
# Santa Cruz          14
# Lake                14
# Trinity             13
# Madera              13
# Lassen              13
# Tuolumne            12
# Yuba                12
# Calaveras           12
# Imperial            12
# Tehama              10
# Sierra              10
# Napa                 9
# Mariposa             9
# Sutter               9
# Modoc                9
# Nevada               9
# Mono                 8
# Glenn                7
# Kings                7
# Amador               7
# Inyo                 6
# Colusa               6
# San Benito           5
# Del Norte            5
# Alpine               2
# Name: zip_code, dtype: int64
